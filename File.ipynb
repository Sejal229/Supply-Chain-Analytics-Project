# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# **Summary of the dataset**
#
# This dataset acts as a Supply Chain Efficiency Monitor, providing a complete view of how products move from suppliers to customers while tracking time, inventory, and costs. It is structured around three key areas: logistics, which helps identify delays in processing and shipping; inventory, which ensures optimal stock levels and highlights risks like shortages or overstocking; and financials, which evaluate overall profitability by analyzing sales and various costs. Together, these elements make the dataset a powerful diagnostic tool that helps identify inefficiencies, reduce costs, and improve overall business performance.

# %%
df = pd.read_csv("C:/Users/acer/OneDrive/Desktop/Supply_chain/Dataset/supply_chain.csv")

df.shape
# Out:
# (500, 20)

# %% [markdown]
# **Column Description**
#
# Warehouse ID : The ID of the warehouse
#
# Location : Warehouse Location
#
# Current Stock : Present Quantity
#
# Demand_Forecast: Expected future demand
#
# Lead_Time_Days: Time taken to restock items
#
# Shipping_Time_Days: Time taken to deliver orders
#
# Stockout_Risk: Risk of running out of stock
#
# Operational_Cost: Daily/overall operating cost
#
# Supplier_ID: Unique ID of supplier
#
# Product_Category: Type of product
#
# Monthly_Sales: Total sales per month
#
# Order_Processing_Time: Time to process an order
#
# Return_Rate: Percentage of returned products
#
# Customer_Rating: Customer feedback score
#
# Warehouse_Capacity: Maximum storage limit
#
# Storage_Cost: Cost of storing goods
#
# Transportation_Cost: Cost of shipping goods
#
# Backorder_Quantity: Orders not fulfilled due to low stock
#
# Damaged_Goods: Number of damaged items
#
# Employee_count : no. of employees works in a warehouse.

# %%
df.head()
# Out:
#   Warehouse_ID Location  Current_Stock  Demand_Forecast  Lead_Time_Days  \
# 0        WH239   Dallas           3926              484               8
# 1        WH244  Houston           3032             5122               3
# 2        WH340  Chicago           4763             4343               5
# 3        WH428  Atlanta           2219              777               7
# 4        WH202   Dallas            809             4756               2
#
#    Shipping_Time_Days  Stockout_Risk  Operational_Cost Supplier_ID  \
# 0                   3              7             93895        S693
# 1                   6             25             46847        S880
# 2                   5             16             64176        S116
# 3                   6             15             38940        S431
# 4                   7             16             33933        S821
#
#   Product_Category  Monthly_Sales  Order_Processing_Time  Return_Rate  \
# ...

# %%
df.tail()
# Out:
#     Warehouse_ID  Location  Current_Stock  Demand_Forecast  Lead_Time_Days  \
# 495        WH145  New York           4357             1521              10
# 496        WH181     Miami           3110             3322               4
# 497        WH068   Seattle           1636             4170               4
# 498        WH204   Seattle           1821              536               9
# 499        WH047    Dallas           2309             3122               7
#
#      Shipping_Time_Days  Stockout_Risk  Operational_Cost Supplier_ID  \
# 495                   5             20             65281        S830
# 496                   7              8             88426        S663
# 497                   3              6             87751        S961
# 498                   6             23             78229        S966
# 499                   3             16             84305        S185
#
#     Product_Category  Monthly_Sales  Order_Processing_Time  Return_Rate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Warehouse_ID           500 non-null    object
#  1   Location               500 non-null    object
#  2   Current_Stock          500 non-null    int64
#  3   Demand_Forecast        500 non-null    int64
#  4   Lead_Time_Days         500 non-null    int64
#  5   Shipping_Time_Days     500 non-null    int64
#  6   Stockout_Risk          500 non-null    int64
#  7   Operational_Cost       500 non-null    int64
#  8   Supplier_ID            500 non-null    object
#  9   Product_Category       500 non-null    object
#  10  Monthly_Sales          500 non-null    int64
#  11  Order_Processing_Time  500 non-null    float64
#  12  Return_Rate            500 non-null    float64
#  13  Customer_Rating        500 non-null    float64
# ...

# %%
df['Location'].value_counts(dropna=False)
# Out:
# Location
# Miami            56
# Atlanta          55
# Los Angeles      54
# New York         54
# San Francisco    52
# Dallas           51
# Denver           46
# Houston          44
# Chicago          44
# Seattle          44
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Current_Stock  Demand_Forecast  Lead_Time_Days  Shipping_Time_Days  \
# count     500.000000       500.000000      500.000000          500.000000
# mean     2722.822000      2957.050000        5.958000            3.948000
# std      1314.878786      1398.763988        2.630223            1.921635
# min       519.000000       402.000000        2.000000            1.000000
# 25%      1565.250000      1745.750000        4.000000            2.000000
# 50%      2670.000000      3094.000000        6.000000            4.000000
# 75%      3842.750000      4152.500000        8.000000            6.000000
# max      4998.000000      5200.000000       10.000000            7.000000
#
#        Stockout_Risk  Operational_Cost  Monthly_Sales  Order_Processing_Time  \
# count     500.000000        500.000000     500.000000             500.000000
# mean       14.944000      65886.354000    5335.572000               2.750462
# ...

# %% [markdown]
# **Total Order Cycle Time: Total number of days taken for a customer to receive an order**

# %%
df['Total_order_cycle_time'] = df['Order_Processing_Time'] + df['Shipping_Time_Days']

# %% [markdown]
# **Total Logistics Cost: Total cost of all logistics operations combined**

# %%
df['Total_Logistics_Cost'] = df['Storage_Cost'] + df['Transportation_Cost'] + df['Operational_Cost']

# %% [markdown]
# **5. Profit Margin (Approx): Difference between sales and cost**

# %%
df['Net_profit'] = df['Monthly_Sales'] - (df['Total_Logistics_Cost'])

# %%
df[['Monthly_Sales', 'Net_profit']].head()
# Out:
#    Monthly_Sales  Net_profit
# 0           4893     -108755
# 1           4453      -57981
# 2           5956      -81518
# 3           5814      -63545
# 4           2279      -52569

# %%
df['Cost_Efficiency_Ratio'] = df['Total_Logistics_Cost'] / df['Monthly_Sales']

# %% [markdown]
# **Capacity Utilization: Percentage of warehouse space being used**

# %%
df['Capacity_Utilization'] = (df['Current_Stock'] / df['Warehouse_Capacity']) * 100

# %% [markdown]
# **Inventory Turnover Ratio: How quickly the stock is sold and replaced**

# %%
df['Inventory_Turnover_Ratio'] = df['Monthly_Sales'] / df['Current_Stock']

# %% [markdown]
# **Will we run out of stock soon**

# %%
df['Stock_to_Demand_Ratio'] = df['Current_Stock'] / df['Demand_Forecast']

# %%
df.replace([np.inf, -np.inf], 0, inplace=True)

# %%
df.columns
# Out:
# Index(['Warehouse_ID', 'Location', 'Current_Stock', 'Demand_Forecast',
#        'Lead_Time_Days', 'Shipping_Time_Days', 'Stockout_Risk',
#        'Operational_Cost', 'Supplier_ID', 'Product_Category', 'Monthly_Sales',
#        'Order_Processing_Time', 'Return_Rate', 'Customer_Rating',
#        'Warehouse_Capacity', 'Storage_Cost', 'Transportation_Cost',
#        'Backorder_Quantity', 'Damaged_Goods', 'Employee_Count',
#        'Total_order_cycle_time', 'Total_Logistics_Cost', 'Net_profit',
#        'Cost_Efficiency_Ratio', 'Capacity_Utilization',
#        'Inventory_Turnover_Ratio', 'Stock_to_Demand_Ratio'],
#       dtype='object')

# %%
new_cols = ['Total_order_cycle_time', 'Total_Logistics_Cost', 'Net_profit', 
            'Cost_Efficiency_Ratio', 'Capacity_Utilization', 
            'Inventory_Turnover_Ratio', 'Stock_to_Demand_Ratio']


df[new_cols].isnull().sum()
# Out:
# Total_order_cycle_time      0
# Total_Logistics_Cost        0
# Net_profit                  0
# Cost_Efficiency_Ratio       0
# Capacity_Utilization        0
# Inventory_Turnover_Ratio    0
# Stock_to_Demand_Ratio       0
# dtype: int64

# %%
df[new_cols].describe()
# Out:
#        Total_order_cycle_time  Total_Logistics_Cost     Net_profit  \
# count              500.000000            500.000000     500.000000
# mean                 6.698462          84151.274000  -78815.702000
# std                  2.323192          21931.164833   22219.320918
# min                  1.568792          36523.000000 -130570.000000
# 25%                  4.976415          65828.500000  -97483.000000
# 50%                  6.628393          84625.000000  -78697.000000
# 75%                  8.418528         102163.250000  -61388.750000
# max                 11.899859         132412.000000  -28877.000000
#
#        Cost_Efficiency_Ratio  Capacity_Utilization  Inventory_Turnover_Ratio  \
# count             500.000000            500.000000                500.000000
# mean               22.653077             11.097874                  2.735464
# std                17.934339              8.208686                  2.609801
# ...

# %%
df.to_csv('Final_Supply_Chain_Analysis.csv', index=False)
